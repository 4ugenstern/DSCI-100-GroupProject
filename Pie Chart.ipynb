# %%
library(tidyverse)
install.packages("formattable")                              
library("formattable")

url="https://raw.githubusercontent.com/4ugenstern/DSCI-100-GroupProject/main/american_bankruptcy.csv"
download.file(url, "data.csv")

raw_data<-read_csv("data.csv")
head(raw_data)

alive<-filter(raw_data, status_label=="alive")
nrow(raw_data)
nrow(alive)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Rows: 78682 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): company_name, status_label
# dbl (19): year, X1, X2, X3, X4, X5, X6, X7, X8, X9, X10, X11, X12, X13, X14,...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   company_name status_label year X1      X2      X3     X4     X5      X6
# 1 C_1          alive        1999 511.267 833.107 18.373 89.031 336.018  35.163
# 2 C_1          alive        2000 485.856 713.811 18.577 64.367 320.590  18.531
# 3 C_1          alive        2001 436.656 526.477 22.496 27.207 286.588 -58.939
# 4 C_1          alive        2002 396.412 496.747 27.172 30.745 259.954 -12.410
# 5 C_1          alive        2003 432.204 523.302 26.680 47.491 247.245   3.504
# ...

# %%
pie_data<-c(73462, 5220)
pie_labels<-c("Alive", "Bankrupt")

pie(pie_data, labels=percent(pie_data/sum(pie_data)), col=slice_colors, main= "Distribution of Company Statuses in Raw Dataset")


legend("topright",
                   legend=status_label,
                   fill=slice_colors,
                   title="Company Status")
# Out:
# Plot with title “Distribution of Company Statuses in Raw Dataset”
